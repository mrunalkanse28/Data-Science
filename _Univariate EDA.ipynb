# %% [markdown]
# Univariate is derived from 'Uni' meaning single and 'Variate' refers to variable.

# %% [markdown]
# Data is of two types: Numerical and Categorical. Univariate EDA for both the types are different. For Categorical we can use count, percentage of each category and for visualization we can use bar chart, pie charts , etc. For numerical Data univariate EDA includes mean,median,mode,std,dev,variance,quartiles,min,max(Descriptive statistics) and visualization includes histogram,boxplot,pie charts.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank_data_clean.csv')
df.head()
# Out:
#    Unnamed: 0   age  salary  balance  marital targeted default housing loan  \
# 0           0  58.0  100000     2143  married      yes      no     yes   no
# 1           1  44.0   60000       29   single      yes      no     yes   no
# 2           2  33.0  120000        2  married      yes      no     yes  yes
# 3           3  47.0   20000     1506  married       no      no     yes   no
# 4           4  33.0       0        1   single       no      no      no   no
#
#    contact  ...  month duration  campaign  pdays  previous  poutcome response  \
# 0  unknown  ...    may     4.35         1    NaN         0   unknown       no
# 1  unknown  ...    may     2.52         1    NaN         0   unknown       no
# 2  unknown  ...    may     1.27         1    NaN         0   unknown       no
# 3  unknown  ...    may     1.53         1    NaN         0   unknown       no
# 4  unknown  ...    may     3.30         1    NaN         0   unknown       no
#
#             job  education  year
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'salary', 'balance', 'marital', 'targeted',
#        'default', 'housing', 'loan', 'contact', 'day', 'month', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'response', 'job',
#        'education', 'year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# age               0
# salary            0
# balance           0
# marital           0
# targeted          0
# default           0
# housing           0
# loan              0
# contact           0
# day               0
# month             0
# duration          0
# campaign          0
# pdays         30728
# previous          0
# poutcome          0
# response          0
# job               0
# education         0
# year              0
# dtype: int64

# %%
df.drop('pdays',axis=1,inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# previous      0
# poutcome      0
# response      0
# job           0
# education     0
# year          0
# dtype: int64

# %%
df.drop('Unnamed : 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.drop('Unnamed : 0',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df['age'].describe()
# Out:
# count    37528.000000
# mean        40.634087
# std         10.442142
# min         18.000000
# 25%         32.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df['age'].median()
# Out:
# 39.0

# %%
df['age'].mode()
# Out:
# 0    32.0
# Name: age, dtype: float64

# %% [markdown]
# ### Histogram of age column

# %%
plt.figure(figsize=(10,8))

plt.hist(df.age, bins = 20)
plt.title('AGE DISTRIBUTION')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Boxplot of age column

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x =df.age)
plt.title('AGE DISTRIBUTION')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['marital'].describe()
# Out:
# count       37528
# unique          3
# top       married
# freq        22506
# Name: marital, dtype: object

# %%
df['marital'].value_counts()
# Out:
# marital
# married     22506
# single      10648
# divorced     4374
# Name: count, dtype: int64

# %%
(df['marital'].value_counts()/df['marital'].count())*100
((df['marital'].value_counts()/df['marital'].count())*100).round(2) # second type
# Out:
# marital
# married     59.97
# single      28.37
# divorced    11.66
# Name: count, dtype: float64

# %%
# marital column:piechart and barplot
#salary and balance columns do everything

# %%
value df['marital'].value_counts(normalize=True).round(2) #normalize = True is return direct percentage and its by default value is False
# Out:
#   Cell In[17], line 1
#     value df['marital'].value_counts(normalize=True).round(2) #normalize = True is return direct percentage and its by default value is False
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Pie chart of marital column

# %%
label=['Married','Single','Divorced']
data=[60,28,12]
plt.figure(figsize=(4,4))
plt.pie(data,labels = label,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Barplot of marital column

# %%
label=['Married','Single','Divorced']
data=[60,28,12]
fig = plt.figure(figsize = (6, 3))
plt.bar(label,data)
plt.show()

# %%
df['salary'].describe()
# Out:
# count     37528.000000
# mean      56574.877425
# std       31917.744928
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
df['balance'].describe()
# Out:
# count    37528.000000
# mean       634.422564
# std        841.040738
# min      -1944.000000
# 25%         44.000000
# 50%        343.000000
# 75%        970.000000
# max       3462.000000
# Name: balance, dtype: float64

# %% [markdown]
# ### Histogram of salary column

# %%
plt.figure(figsize=(10,8))

plt.hist(df.salary, bins = 10)
plt.title('SALARY INFO')
plt.xlabel('salary')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Boxplot of Salary column

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x =df.salary)
plt.title('SALARY INFO')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
df['salary'].describe()
# Out:
# count     37528.000000
# mean      56574.877425
# std       31917.744928
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
df['marital'].value_counts()
# Out:
# marital
# married     22506
# single      10648
# divorced     4374
# Name: count, dtype: int64

# %%
(df['salary'].value_counts()/df['salary'].count())*100
# Out:
# salary
# 20000     21.996909
# 60000     20.376785
# 100000    20.107653
# 50000     11.844489
# 70000      9.494244
# 55000      4.684502
# 120000     3.298870
# 8000       2.747282
# 16000      2.712641
# 4000       2.115754
# 0          0.620870
# Name: count, dtype: float64

# %% [markdown]
# ### Piechart of salary column

# %%
sal=[20000,60000,100000,50000,70000,55000,120000,8000,16000,4000,0]
data=[22,20,20,12,9,5,3,3,3,2,1]
plt.figure(figsize=(9,10))
plt.pie(data,labels = sal,autopct='%1.1f%%')
plt.show()

# %%
sal=[20000,60000,100000,50000,70000,55000,120000,8000,16000,4000,0]
data=[22,20,20,12,9,5,3,3,3,2,1]
fig = plt.figure(figsize = (6, 7))
plt.bar(sal,data)
plt.show()
