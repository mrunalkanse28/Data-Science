# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
super_store = pd.read_excel('Superstore+Dataset+-+Analysis+.xlsx')
super_store.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
selected_store = ['Sales','Quantity','Discount','Profit']
selected_store
# Out:
# ['Sales', 'Quantity', 'Discount', 'Profit']

# %%
description_super_store = super_store[['Sales','Quantity','Discount','Profit']].describe().round(2)
description_super_store
# Out:
#           Sales  Quantity  Discount   Profit
# count   9994.00   9994.00   9994.00  9994.00
# mean     229.86      3.79      0.16    28.66
# std      623.25      2.23      0.21   234.26
# min        0.44      1.00      0.00 -6599.98
# 25%       17.28      2.00      0.00     1.73
# 50%       54.49      3.00      0.20     8.67
# 75%      209.94      5.00      0.20    29.36
# max    22638.48     14.00      0.80  8399.98

# %%
description_super_store.shape
# Out:
# (8, 4)

# %%
description_super_store.columns
# Out:
# Index(['Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
description_super_store.index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
description_super_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sales     8 non-null      float64
#  1   Quantity  8 non-null      float64
#  2   Discount  8 non-null      float64
#  3   Profit    8 non-null      float64
# dtypes: float64(4)
# memory usage: 320.0+ bytes

# %% [markdown]
# #### Dataframe has 4 attribute:
# - Shape
#
# - Column
#
# - Index
#
# - Info

# %%
description_super_store.isnull().sum()
# Out:
# Sales       0
# Quantity    0
# Discount    0
# Profit      0
# dtype: int64

# %%
super_store.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
super_store.isnull().count(True)
# Out:
# 0       21
# 1       21
# 2       21
# 3       21
# 4       21
#         ..
# 9989    21
# 9990    21
# 9991    21
# 9992    21
# 9993    21
# Length: 9994, dtype: int64

# %%
plt.plot(super_store['Sales'],super_store['Quantity'])
plt.show()

# %%
plt.scatter(super_store['Sales'],super_store['Quantity'])
plt.show()

# %%
plt.plot(super_store['Sales'],super_store['Quantity'],color='black')
plt.show()

# %%
x = [1,2,3]
y = [1,2,3]

plt.plot(x,y)

# %%
x = [1,2,3]
y = [4,6,5]

plt.plot(x,y)

# %%
x = pd.Series(range(0,20,2))
y = pd.Series(range(10))

plt.plot(x,y,color = 'green',marker='*',linestyle='--')

# %%
x = pd.Series(range(0,20,2))
y = x**2

plt.plot(x,y,color = 'green',marker='*',linestyle='--')

# %%
x = pd.Series(range(0,20,2))
y = np.sqrt(x)

plt.plot(x,y,color = 'green',marker='*',linestyle='--')

# %%
x = pd.Series(range(1,20,2))
y = np.log(x)
plt.figure(figsize=(7,8)) # 7 define length and 8 define height
plt.plot(x,y,color = 'green',marker='*',linestyle='--') # marker used for highlight coordinates and linestyle used for type of line
plt.title('Log of first 10 even numbers',weight='bold')
plt.xlabel('Numbers')
plt.ylabel('Log of numbers')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.legend('Log Function')
plt.show()

# %%
data = {
 'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
 'Stock Price': [150, 155, 160, 162, 158, 165, 170, 172, 168, 175, 180, 185]
}
df = pd.DataFrame(data)
plt.figure(figsize=(6,3))
plt.plot(df['Month'],df['Stock Price'],marker='o',color='b')
sns.set_style('darkgrid')
plt.show()

# %%
x1 = [1,2,3,4,5,6,7,3,6,8]
y1 = [99,93,92,94,95,96,35,45,24,33]
for i in range(len(x1)):
    label = f'({x1[i]},{y1[i]})'
    plt.text(x1[i],y1[i],label,fontsize = 9, ha='right')
plt.scatter(x1,y1,color='black',marker='*')
plt.show()

# %%
x = pd.Series(range(0,20,2))
y = pd.Series(range(10))

plt.figure(figsize=(6,3))
plt.scatter(x,y, marker='*',color='red')
plt.show()

# %%
data = {
 'Year': [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
 'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
 'Stock Price': [150, 155, 160, 162, 158, 165, 170, 172, 168, 175, 180, 185]
}
df = pd.DataFrame(data)

plt.figure(figsize=(6,3))
sns.scatterplot(x = 'Month',y = 'Stock Price',data=df,hue='Year',palette='Set2',markers='o')
plt.legend(title='Year',bbox_to_anchor=(1,1),loc='upper left')
plt.show()
