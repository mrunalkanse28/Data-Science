# %% [markdown]
# ### Bivariate EDA

# %%
# It involves two variables. Focusses on understanding the relationship between two variables using co-relation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank_data_clean.csv')
df.head()
# Out:
#    Unnamed: 0   age  salary  balance  marital targeted default housing loan  \
# 0           0  58.0  100000     2143  married      yes      no     yes   no
# 1           1  44.0   60000       29   single      yes      no     yes   no
# 2           2  33.0  120000        2  married      yes      no     yes  yes
# 3           3  47.0   20000     1506  married       no      no     yes   no
# 4           4  33.0       0        1   single       no      no      no   no
#
#    contact  ...  month duration  campaign  pdays  previous  poutcome response  \
# 0  unknown  ...    may     4.35         1    NaN         0   unknown       no
# 1  unknown  ...    may     2.52         1    NaN         0   unknown       no
# 2  unknown  ...    may     1.27         1    NaN         0   unknown       no
# 3  unknown  ...    may     1.53         1    NaN         0   unknown       no
# 4  unknown  ...    may     3.30         1    NaN         0   unknown       no
#
#             job  education  year
# 0    management   tertiary  2017
# 1    technician  secondary  2017
# 2  entrepreneur  secondary  2017
# 3   blue-collar    unknown  2017
# 4       unknown    unknown  2017
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'salary', 'balance', 'marital', 'targeted',
#        'default', 'housing', 'loan', 'contact', 'day', 'month', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'response', 'job',
#        'education', 'year'],
#       dtype='object')

# %% [markdown]
# #### Numeric_numeric EDA:
# 1. Scatterplot
# 2. Pairplot
# 3. Correlation

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df.age, y=df.salary)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
correl = df[['age','salary']].corr()
correl
# Out:
#              age    salary
# age     1.000000  0.023844
# salary  0.023844  1.000000

# %%
correl1 = df[['balance','salary']].corr()
correl1
# Out:
#           balance    salary
# balance  1.000000  0.023575
# salary   0.023575  1.000000

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df.balance, y=df.salary)
# Out:
# <Axes: xlabel='balance', ylabel='salary'>

# %%
correl1 = df[['age','balance','salary']].corr()
correl1
# Out:
#               age   balance    salary
# age      1.000000  0.094734  0.023844
# balance  0.094734  1.000000  0.023575
# salary   0.023844  0.023575  1.000000

# %%
plt.figure(figsize=(20,10))
sns.pairplot(data=df,vars=['age','balance','salary'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(correl1, annot=True, cmap='Reds') # annot=True is used for printing values of correlation and cmap is used for colour
plt.show()

# %% [markdown]
# ### Numeric-Categorical data EDA:
# 1. Boxplot
# 2. Barplot

# %%
df1 = df.groupby('response')['salary'].mean()
df1
# Out:
# response
# no     56401.456466
# yes    58527.605358
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df,x='response',y='salary')
plt.show()

# %%
df1 = df.groupby('response')['salary'].median()
df1
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
df1 = df.groupby('response')['salary'].quantile(0.25)
df1
# Out:
# response
# no     20000.0
# yes    50000.0
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df,x='response',y='balance')
plt.show()

# %%
df1 = df.groupby('response')['balance'].median()
df1
# Out:
# response
# no     325.0
# yes    567.0
# Name: balance, dtype: float64
