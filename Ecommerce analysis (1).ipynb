# %%
import numpy as np
import pandas as pd

# %%
ecom_an = pd.read_excel('Excel_Module_Ecommerce_Analysis_v3.xlsx')
ecom_an
# Out:
#       order_id product_category destination_city origin_city  \
# 0       318813               PC        Delhi, DL   Bangalore
# 1        70870           Laptop       Mumbai, MH   Bangalore
# 2       719174           Mobile      Kolkata, WB       Delhi
# 3       482982           Mobile        Delhi, DL       Delhi
# 4       217738           Laptop      Kolkata, WB       Delhi
# ...        ...              ...              ...         ...
# 4995     45753           Mobile        Delhi, DL   Bangalore
# 4996     92432           Laptop      Chennai, TN   Bangalore
# 4997    783527           Laptop    Bangalore, KA   Bangalore
# 4998    371741               PC      Chennai, TN   Bangalore
# 4999    962768           Mobile      Chennai, TN       Delhi
#
#          logistics_provider_id final_delivery_status       dispatch_date  \
# 0          Ship2Home  delivery             Delivered 2019-03-01 00:03:36
# 1     Ship2Home Logistics Unit             Delivered 2019-03-01 00:06:46
# ...
