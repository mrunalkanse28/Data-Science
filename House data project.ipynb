# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#dropping the columns
df = df.drop(columns=['date','yr_built','yr_renovated','id','zipcode'],inplace=True)

# %%
#changing datatype of price
df['price'] = df['price'].astype(int)

# %%
sns.histplot(data=df,x='price')
plt.show()

# %%
sns.scatterplot(data=df,y='price',x='sqft_living')
plt.show()

# %% [markdown]
# **Removing Outliers**

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df[['price', 'sqft_living']].quantile(0.25)
Q3 = df[['price', 'sqft_living']].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Filter out outliers based on IQR
data_clean = df[((df[['price', 'sqft_living']] < (Q1 - 1.5 * IQR)) | (df[['price', 'sqft_living']] > (Q3 + 1.5 * IQR))).any(axis=1)]
data_clean
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 21     2524049179  20140826T000000  2000000         3       2.75         3050
# 49      822039084  20150311T000000  1350000         3       2.50         2753
# 69     1802000060  20140612T000000  1325000         5       2.25         3200
# 70     1525059190  20140912T000000  1040000         5       3.25         4770
# ...           ...              ...      ...       ...        ...          ...
# 21568   524059330  20150130T000000  1700000         4       3.50         3830
# 21576  9253900271  20150107T000000  3567000         5       4.50         4850
# 21590  7430200100  20140514T000000  1222500         4       3.50         4910
# 21597   191100405  20150421T000000  1575000         4       3.25         3410
# 21600   249000205  20141015T000000  1537000         5       3.75         4470
#
# ...

# %% [markdown]
# ### Correlation

# %%
targeted_variables = data_clean[[ 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
        'waterfront', 'view',  'grade', 'sqft_above',
       'sqft_basement', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15']]

# %%
sns.heatmap(data=targeted_variables.corr())
plt.show()

# %%
data_targetted = data_clean[['sqft_living','bedrooms','bathrooms','price']]
corr_matrix = data_targetted.corr()
print(corr_matrix)
# Out:
#              sqft_living  bedrooms  bathrooms     price
# sqft_living     1.000000  0.399933   0.699667  0.402167
# bedrooms        0.399933  1.000000   0.439106  0.072892
# bathrooms       0.699667  0.439106   1.000000  0.332067
# price           0.402167  0.072892   0.332067  1.000000

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data_targetted,hue='price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Machine Leaning

# %%
X = data_targetted.drop(columns=['price','sqft_living'])
y = data_clean['price']

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=45)

# %%
len(X_train), len(X_test), len(y_train),len(y_test)
# Out:
# (885, 436, 885, 436)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
test_1 = mean_absolute_error(y_test,prediction)
test_2 = mean_squared_error(y_test,prediction)
test_3 = r2_score(y_test,prediction)

# %%
print("Mean Absolute Error:", test_1)
print("Mean Squared Error:", test_2)
print("R squared Error:", test_3)
# Out:
# Mean Absolute Error: 448749.8980515179
# Mean Squared Error: 452914712798.46497
# R squared Error: 0.09256855509161599

# %%
df_error = y_test - prediction
sns.scatterplot(x=y_test,y=df_error)
plt.axhline(y=0, color='red',ls='--') #ls = line style
plt.show()

# %%
df_error.mean()
sns.distplot(df_error,bins=30,kde=True)
plt.show()
# Out:
# C:\Users\siddhijain\AppData\Local\Temp\ipykernel_6220\4001180633.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_error,bins=30,kde=True)

# %% [markdown]
# ## OLS estimates

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X)

# %%
model = sm.OLS(y,X).fit()  
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     87.20
# Date:                Thu, 10 Oct 2024   Prob (F-statistic):           2.72e-36
# Time:                        11:25:22   Log-Likelihood:                -19514.
# No. Observations:                1321   AIC:                         3.903e+04
# Df Residuals:                    1318   BIC:                         3.905e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.948e+05   8.64e+04     10.357      0.000    7.25e+05    1.06e+06
# ...
